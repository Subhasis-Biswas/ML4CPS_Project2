# %% [markdown]
# # Data Loading and Checking

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.manifold import MDS
from sklearn.manifold import TSNE
from scipy.spatial import procrustes
from scipy.spatial.distance import jensenshannon

# %%
plt.style.use('ggplot')
# set the font size of the plots
plt.rcParams.update({'font.size': 6})

data=pd.read_csv('combined_data_with_loc.csv')
#load feature category mapping
feature_category_dict=json.load(open('feature_category_dict.json'))
data.head()
# Out:
#   Community Name                             Region  Map reference  \
# 0     Ascot Vale  Northern and Western Metropolitan              4
# 1      Braybrook  Northern and Western Metropolitan              4
# 2    Craigieburn  Northern and Western Metropolitan              2
# 3        Croydon               Eastern Metropolitan              2
# 4        Fawkner  Northern and Western Metropolitan              4
#
#   Grid reference               Location  Population Density  \
# 0             B3    6km NW of Melbourne         3758.623596
# 1             A3  10km WNW of Melbourne         2025.468296
# 2             A3    27km N of Melbourne         1034.970870
# 3             B4    28km E of Melbourne         1730.064830
# 4             C1    12km N of Melbourne         2619.120089
#
#    Travel time to GPO (minutes)  Distance to GPO (km)                LGA  \
# 0                      9.360142              6.958742  Moonee Valley (C)
# 1                     15.131666             11.595888    Maribyrnong (C)
# 2                     31.994666             43.100287           Hume (C)
# 3                     28.992647             34.071323      Maroondah (C)
# 4                     17.405267             13.047142       Moreland (C)
#
#                             Primary Care Partnership  ...  \
# 0          Inner North West Primary Care Partnership  ...
# 1  HealthWest (b): Hobson's Bay, Maribyrnong, Wyn...  ...
# 2           Hume-Whittlesea Primary Care Partnership  ...
# 3                Outer East Primary Care Partnership  ...
# 4          Inner North West Primary Care Partnership  ...
#
#   Presentations to emergency departments, 2012-13  \
# 0                                     3313.052180
# 1                                     2632.949379
# 2                                     9915.723721
# 3                                     6149.574954
# 4                                     3799.030890
#
#    Nearest public hospital with emergency department  \
# 0                           Royal Melbourne Hospital
# 1                           Royal Melbourne Hospital
# 2                              The Northern Hospital
# 3                                 Maroondah Hospital
# 4                              The Northern Hospital
#
#    Travel time to nearest public hospital with emergency department  \
# 0                                           6.630953
# 1                                          12.824977
# 2                                          11.570855
# 3                                           5.093285
# 4                                          11.510757
#
#    Distance to nearest public hospital with emergency department  \
# 0                                           4.993841
# 1                                          10.161988
# 2                                          15.213189
# 3                                           3.601752
# 4                                          12.004044
#
#    Presentations to emergency departments due to injury  \
# 0                                         679.257076
# 1                                         543.631989
# 2                                        2044.424399
# 3                                        1754.954941
# 4                                         680.401318
#
#   Presentations to emergency departments due to injury, %  \
# 0                                          20.502456
# 1                                          20.647263
# 2                                          20.618005
# 3                                          28.537825
# 4                                          17.909865
#
#   Category 4 & 5 emergency department presentations  \
# 0                                       1864.918123
# 1                                       1683.966712
# 2                                       5102.134434
# 3                                       3062.182462
# 4                                       1942.874353
#
#    Category 4 & 5 emergency department presentations, %     cart_x  \
# 0                                          56.290032     -4.242641
# 1                                          63.957428     -9.238795
# 2                                          51.454988      0.000000
# 3                                          49.795026     28.000000
# 4                                          51.141315      0.000000
#
#          cart_y
# 0  4.242641e+00
# 1  3.826834e+00
# 2  2.700000e+01
# 3  1.714506e-15
# 4  1.200000e+01
#
# [5 rows x 228 columns]

# %%
hospital_features=feature_category_dict['Hospital']

hospital_data=data[hospital_features]

# compute the number of missing values in each column
missing_values=hospital_data.isnull().sum()

print('Number of missing values in each column')
# also print the type of each column

for i in range(len(missing_values)):
    print(f'{hospital_data.columns[i]}: {missing_values.iloc[i]} missing values ::: dtype: {hospital_data.dtypes.iloc[i]}')


hospital_data.head()
# Out:
# Number of missing values in each column
# Public hospital separations, 2012-13: 0 missing values ::: dtype: float64
# Nearest Public Hospital: 0 missing values ::: dtype: object
# Travel time to nearest public hospital: 0 missing values ::: dtype: float64
# Distance to nearest public hospital: 0 missing values ::: dtype: float64
# Obstetric type separations, 2012-13: 0 missing values ::: dtype: object
# Nearest public hospital with maternity services: 0 missing values ::: dtype: object
# Time to nearest public hospital with maternity services: 0 missing values ::: dtype: float64
# Distance to nearest public hospital with maternity services: 0 missing values ::: dtype: float64
# Presentations to emergency departments, 2012-13: 0 missing values ::: dtype: float64
# Nearest public hospital with emergency department: 0 missing values ::: dtype: object
# Travel time to nearest public hospital with emergency department: 0 missing values ::: dtype: float64
# Distance to nearest public hospital with emergency department: 0 missing values ::: dtype: float64
# Presentations to emergency departments due to injury: 0 missing values ::: dtype: float64
# Presentations to emergency departments due to injury, %: 0 missing values ::: dtype: float64
# Category 4 & 5 emergency department presentations: 0 missing values ::: dtype: float64
# Category 4 & 5 emergency department presentations, %: 0 missing values ::: dtype: float64
#    Public hospital separations, 2012-13       Nearest Public Hospital  \
# 0                           2701.557647  Western Hospital (Footscray)
# 1                           2964.691696  Western Hospital (Footscray)
# 2                           9644.630863    Craigieburn Health Service
# 3                           5781.347185            Maroondah Hospital
# 4                           4694.587633   Broadmeadows Health Service
#
#    Travel time to nearest public hospital  \
# 0                                5.254528
# 1                                5.028871
# 2                                7.280902
# 3                                5.093285
# 4                                8.910941
#
#    Distance to nearest public hospital Obstetric type separations, 2012-13  \
# 0                             3.876415                   215.5550042481527
# 1                             3.875731                  189.98005347998108
# 2                             7.277191                   918.9149121263106
# 3                             3.601752                  317.51605093008055
# 4                             6.645261                   287.0439496672183
#
#   Nearest public hospital with maternity services  \
# 0                          Royal Women's Hospital
# 1                               Sunshine Hospital
# 2                           The Northern Hospital
# 3                             Yarra Ranges Health
# 4                           The Northern Hospital
#
#    Time to nearest public hospital with maternity services  \
# 0                                           6.490453
# 1                                           8.071881
# 2                                          11.570855
# 3                                          10.683462
# 4                                          11.510757
#
#    Distance to nearest public hospital with maternity services  \
# 0                                           4.912570
# 1                                           6.216803
# 2                                          15.213189
# 3                                           9.413847
# 4                                          12.004044
#
#    Presentations to emergency departments, 2012-13  \
# 0                                      3313.052180
# 1                                      2632.949379
# 2                                      9915.723721
# 3                                      6149.574954
# 4                                      3799.030890
#
#   Nearest public hospital with emergency department  \
# 0                          Royal Melbourne Hospital
# 1                          Royal Melbourne Hospital
# 2                             The Northern Hospital
# 3                                Maroondah Hospital
# 4                             The Northern Hospital
#
#    Travel time to nearest public hospital with emergency department  \
# 0                                           6.630953
# 1                                          12.824977
# 2                                          11.570855
# 3                                           5.093285
# 4                                          11.510757
#
#    Distance to nearest public hospital with emergency department  \
# 0                                           4.993841
# 1                                          10.161988
# 2                                          15.213189
# 3                                           3.601752
# 4                                          12.004044
#
#    Presentations to emergency departments due to injury  \
# 0                                         679.257076
# 1                                         543.631989
# 2                                        2044.424399
# 3                                        1754.954941
# 4                                         680.401318
#
#    Presentations to emergency departments due to injury, %  \
# 0                                          20.502456
# 1                                          20.647263
# 2                                          20.618005
# 3                                          28.537825
# 4                                          17.909865
#
#    Category 4 & 5 emergency department presentations  \
# 0                                        1864.918123
# 1                                        1683.966712
# 2                                        5102.134434
# 3                                        3062.182462
# 4                                        1942.874353
#
#    Category 4 & 5 emergency department presentations, %
# 0                                          56.290032
# 1                                          63.957428
# 2                                          51.454988
# 3                                          49.795026
# 4                                          51.141315

# %%
numerical_features=hospital_data.select_dtypes(include=[np.number]).columns
categorical_features=hospital_data.select_dtypes(include=[object]).columns

print('Numerical Features\n-----------------')
print(numerical_features)
print()
print('Categorical Features\n-----------------')
print(categorical_features)
# Out:
# Numerical Features
# -----------------
# Index(['Public hospital separations, 2012-13',
#        'Travel time to nearest public hospital',
#        'Distance to nearest public hospital',
#        'Time to nearest public hospital with maternity services',
#        'Distance to nearest public hospital with maternity services',
#        'Presentations to emergency departments, 2012-13',
#        'Travel time to nearest public hospital with emergency department',
#        'Distance to nearest public hospital with emergency department',
#        'Presentations to emergency departments due to injury',
#        'Presentations to emergency departments due to injury, %',
#        'Category 4 & 5 emergency department presentations',
#        'Category 4 & 5 emergency department presentations, %'],
#       dtype='object')
#
# Categorical Features
# -----------------
# Index(['Nearest Public Hospital', 'Obstetric type separations, 2012-13',
#        'Nearest public hospital with maternity services',
#        'Nearest public hospital with emergency department'],
#       dtype='object')

# %%
# get distinct values in the column and their counts
# do a sorted count plot
plt.figure(figsize=(7,5))
sns.countplot(hospital_data['Nearest Public Hospital'],order=hospital_data['Nearest Public Hospital'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Nearest Public Hospital and their counts')
plt.show()

# get distinct values in the column and their counts
print('Nearest Public Hospital and their counts')
print(hospital_data['Nearest Public Hospital'].value_counts())
# print total number of distinct values
print(f'Total number of distinct values: {hospital_data["Nearest Public Hospital"].nunique()}')
# Out:
# Nearest Public Hospital and their counts
# Nearest Public Hospital
# The Alfred                                    6
# Royal Melbourne Hospital                      4
# Caulfield General Medical Centre              3
# Monash Medical Centre (Moorabbin)             3
# Western Hospital (Footscray)                  3
# Broadmeadows Health Service                   3
# Rosebud Hospital                              2
# Frankston Hospital                            2
# Dandenong Hospital                            2
# Sandringham and District Memorial Hospital    2
# Maroondah Hospital                            1
# Craigieburn Health Service                    1
# St Vincent's Hospital                         1
# Monash Medical Centre (Clayton)               1
# Name: count, dtype: int64
# Total number of distinct values: 14

# %%
public_hospital_locs=pd.DataFrame(columns=['Hospital','Latitude','Longitude'])

# append the following row: The Alfred, -37.845612289147745, 144.98187643728176
public_hospital_locs.loc[0]=['The Alfred',-37.845612289147745,144.98187643728176]
# append the following row: Royal Melbourne Hospital, -37.80262360442828, 144.96173916536713
public_hospital_locs.loc[1]=['Royal Melbourne Hospital',-37.80262360442828,144.96173916536713]
# append the following row: Caulfield Hospital, -37.880089505921475, 145.02441076194694
public_hospital_locs.loc[2]=['Caulfield General Medical Centre',-37.880089505921475,145.02441076194694]
# Monash Medical Centre (Moorabbin), -37.92032482993266, 145.0634487962696
public_hospital_locs.loc[3]=['Monash Medical Centre (Moorabbin)',-37.92032482993266,145.0634487962696]
# Western Hospital (Footscray), -37.79201824899151, 144.88719630204199
public_hospital_locs.loc[4]=['Western Hospital (Footscray)',-37.79201824899151,144.88719630204199]
# Broadmeadows Health Service, -37.68440655553534, 144.91233854528704
public_hospital_locs.loc[5]=['Broadmeadows Health Service',-37.68440655553534,144.91233854528704]
# Rosebud Hospital, -38.36138632780765, 144.88472561012955
public_hospital_locs.loc[6]=['Rosebud Hospital',-38.36138632780765,144.88472561012955]
# Frankston Hospital, -38.15040781435954, 145.12994966371912
public_hospital_locs.loc[7]=['Frankston Hospital',-38.15040781435954,145.12994966371912]
# Dandenong Hospital, -37.97616185102236, 145.219651817351
public_hospital_locs.loc[8]=['Dandenong Hospital',-37.97616185102236,145.219651817351]
# Sandringham and District Memorial Hospital, -37.960541512601445, 145.01785345161932
public_hospital_locs.loc[9]=['Sandringham and District Memorial Hospital',-37.960541512601445,145.01785345161932]
# Maroondah Hospital, -37.80659538416403, 145.25453896881348
public_hospital_locs.loc[10]=['Maroondah Hospital',-37.80659538416403,145.25453896881348]
# Craigieburn Health Service, -37.59532980853025, 144.91994637916665
public_hospital_locs.loc[11]=['Craigieburn Health Service',-37.59532980853025,144.91994637916665]
# St Vincent's Hospital, -37.804611445718436, 144.97472872246814
public_hospital_locs.loc[12]=["St Vincent's Hospital",-37.804611445718436,144.97472872246814]
# Monash Medical Centre (Clayton), -37.92011584938465, 145.12228465492174
public_hospital_locs.loc[13]=['Monash Medical Centre (Clayton)',-37.92011584938465,145.12228465492174]
# The Northern Hospital, -37.65139647330335, 145.01575570363147
public_hospital_locs.loc[14]=['The Northern Hospital',-37.65139647330335,145.01575570363147]

public_hospital_locs
# Out:
#                                       Hospital   Latitude   Longitude
# 0                                   The Alfred -37.845612  144.981876
# 1                     Royal Melbourne Hospital -37.802624  144.961739
# 2             Caulfield General Medical Centre -37.880090  145.024411
# 3            Monash Medical Centre (Moorabbin) -37.920325  145.063449
# 4                 Western Hospital (Footscray) -37.792018  144.887196
# 5                  Broadmeadows Health Service -37.684407  144.912339
# 6                             Rosebud Hospital -38.361386  144.884726
# 7                           Frankston Hospital -38.150408  145.129950
# 8                           Dandenong Hospital -37.976162  145.219652
# 9   Sandringham and District Memorial Hospital -37.960542  145.017853
# 10                          Maroondah Hospital -37.806595  145.254539
# 11                  Craigieburn Health Service -37.595330  144.919946
# 12                       St Vincent's Hospital -37.804611  144.974729
# 13             Monash Medical Centre (Clayton) -37.920116  145.122285
# 14                       The Northern Hospital -37.651396  145.015756

# %%
# check if the Hospital names in the public_hospital_locs dataframe are present in the hospital_data dataframe
# if not, print the names of the hospitals that are not present
allOK=True
for i in range(len(public_hospital_locs)):
	if public_hospital_locs['Hospital'].iloc[i] not in hospital_data['Nearest Public Hospital'].values:
		print(public_hospital_locs['Hospital'].iloc[i])
		allOK=False

if allOK: print('All hospitals present')
else: print('Some hospitals missing')

# check if the Hospital names in the hospital_data dataframe are present in the public_hospital_locs dataframe
# if not, print the names of the hospitals that are not present
allOK=True
for i in range(len(hospital_data)):
	if hospital_data['Nearest Public Hospital'].iloc[i] not in public_hospital_locs['Hospital'].values:
		print(hospital_data['Nearest Public Hospital'].iloc[i])
		allOK=False

if allOK: print('All hospitals present')
else: print('Some hospitals missing')
# Out:
# The Northern Hospital
# Some hospitals missing
# All hospitals present

# %%
# save the public_hospital_locs dataframe to a csv file
public_hospital_locs.to_csv('public_hospital_locs.csv',index=False)

# %%
# use geographical coordinates of the hospitals to calculate the co-ordinates relative to Melbourne GPO

# Melbourne GPO co-ordinates
melb_gpo = (-37.81384, 144.963028)

# compute (X,Y) co-ordinates of the hospitals relative to Melbourne GPO, with Melbourne GPO as the origin
dLat = public_hospital_locs['Latitude'] - melb_gpo[0]
dLon = public_hospital_locs['Longitude'] - melb_gpo[1]

# turn to cartesian co-ordinates
# use geopy

from geopy.distance import geodesic

def get_cartesian_coords(lat,lon):
	dN=geodesic((lat,lon),(melb_gpo[0],lon)).km
	dE=geodesic((lat,lon),(lat,melb_gpo[1])).km

	# adjust for the sign
	if lat < melb_gpo[0]:
		dN*=-1
	if lon < melb_gpo[1]:
		dE*=-1

	return dE,dN

public_hospital_locs['cart_x'],public_hospital_locs['cart_y']=zip(*public_hospital_locs.apply(lambda x: get_cartesian_coords(x['Latitude'],x['Longitude']),axis=1))

public_hospital_locs
# Out:
#                                       Hospital   Latitude   Longitude  \
# 0                                   The Alfred -37.845612  144.981876
# 1                     Royal Melbourne Hospital -37.802624  144.961739
# 2             Caulfield General Medical Centre -37.880090  145.024411
# 3            Monash Medical Centre (Moorabbin) -37.920325  145.063449
# 4                 Western Hospital (Footscray) -37.792018  144.887196
# 5                  Broadmeadows Health Service -37.684407  144.912339
# 6                             Rosebud Hospital -38.361386  144.884726
# 7                           Frankston Hospital -38.150408  145.129950
# 8                           Dandenong Hospital -37.976162  145.219652
# 9   Sandringham and District Memorial Hospital -37.960542  145.017853
# 10                          Maroondah Hospital -37.806595  145.254539
# 11                  Craigieburn Health Service -37.595330  144.919946
# 12                       St Vincent's Hospital -37.804611  144.974729
# 13             Monash Medical Centre (Clayton) -37.920116  145.122285
# 14                       The Northern Hospital -37.651396  145.015756
#
#        cart_x     cart_y
# 0    1.658969  -3.526510
# 1   -0.113504   1.244940
# 2    5.400166  -7.353270
# 3    8.829739 -11.819173
# 4   -6.679251   2.422056
# 5   -4.471191  14.366043
# 6   -6.843604 -60.776622
# 7   14.631144 -37.357728
# 8   22.547189 -18.016831
# 9    4.818033 -16.283038
# 10  25.671212   0.804101
# 11  -3.804663  24.252642
# 12   1.030424   1.024304
# 13  14.003062 -11.795977
# 14   4.653041  18.029838

# %%
# plot the hospitals on a map
plt.figure(figsize=(10,10))
plt.scatter(public_hospital_locs['cart_x'],public_hospital_locs['cart_y'],s=200,c='orange')
plt.scatter(data['cart_x'],data['cart_y'],s=100,c='gray')
for i in range(len(public_hospital_locs)):
	plt.text(public_hospital_locs['cart_x'].iloc[i],public_hospital_locs['cart_y'].iloc[i], i,fontsize=7,ha='center',va='center')
# also annotate the suburbs with their index
for i in range(len(data)):
	plt.text(data['cart_x'].iloc[i],data['cart_y'].iloc[i], i,fontsize=6,ha='center',va='center')
plt.grid(True)
plt.xlabel('X (km)')
plt.ylabel('Y (km)')
plt.title('Public Hospitals in Melbourne')
plt.legend(['Public Hospitals','Suburbs'])

plt.savefig('../doc/figures/public_hospitals_map.png')
plt.show()
plt.clf()

# %%
hospital_data.head()
# Out:
#    Public hospital separations, 2012-13       Nearest Public Hospital  \
# 0                           2701.557647  Western Hospital (Footscray)
# 1                           2964.691696  Western Hospital (Footscray)
# 2                           9644.630863    Craigieburn Health Service
# 3                           5781.347185            Maroondah Hospital
# 4                           4694.587633   Broadmeadows Health Service
#
#    Travel time to nearest public hospital  \
# 0                                5.254528
# 1                                5.028871
# 2                                7.280902
# 3                                5.093285
# 4                                8.910941
#
#    Distance to nearest public hospital Obstetric type separations, 2012-13  \
# 0                             3.876415                   215.5550042481527
# 1                             3.875731                  189.98005347998108
# 2                             7.277191                   918.9149121263106
# 3                             3.601752                  317.51605093008055
# 4                             6.645261                   287.0439496672183
#
#   Nearest public hospital with maternity services  \
# 0                          Royal Women's Hospital
# 1                               Sunshine Hospital
# 2                           The Northern Hospital
# 3                             Yarra Ranges Health
# 4                           The Northern Hospital
#
#    Time to nearest public hospital with maternity services  \
# 0                                           6.490453
# 1                                           8.071881
# 2                                          11.570855
# 3                                          10.683462
# 4                                          11.510757
#
#    Distance to nearest public hospital with maternity services  \
# 0                                           4.912570
# 1                                           6.216803
# 2                                          15.213189
# 3                                           9.413847
# 4                                          12.004044
#
#    Presentations to emergency departments, 2012-13  \
# 0                                      3313.052180
# 1                                      2632.949379
# 2                                      9915.723721
# 3                                      6149.574954
# 4                                      3799.030890
#
#   Nearest public hospital with emergency department  \
# 0                          Royal Melbourne Hospital
# 1                          Royal Melbourne Hospital
# 2                             The Northern Hospital
# 3                                Maroondah Hospital
# 4                             The Northern Hospital
#
#    Travel time to nearest public hospital with emergency department  \
# 0                                           6.630953
# 1                                          12.824977
# 2                                          11.570855
# 3                                           5.093285
# 4                                          11.510757
#
#    Distance to nearest public hospital with emergency department  \
# 0                                           4.993841
# 1                                          10.161988
# 2                                          15.213189
# 3                                           3.601752
# 4                                          12.004044
#
#    Presentations to emergency departments due to injury  \
# 0                                         679.257076
# 1                                         543.631989
# 2                                        2044.424399
# 3                                        1754.954941
# 4                                         680.401318
#
#    Presentations to emergency departments due to injury, %  \
# 0                                          20.502456
# 1                                          20.647263
# 2                                          20.618005
# 3                                          28.537825
# 4                                          17.909865
#
#    Category 4 & 5 emergency department presentations  \
# 0                                        1864.918123
# 1                                        1683.966712
# 2                                        5102.134434
# 3                                        3062.182462
# 4                                        1942.874353
#
#    Category 4 & 5 emergency department presentations, %
# 0                                          56.290032
# 1                                          63.957428
# 2                                          51.454988
# 3                                          49.795026
# 4                                          51.141315

# %% [markdown]
# Some groups violate equivariance assumption

# %%
import geopandas as gpd
from pysal.lib import weights
from esda import Moran, Moran_Local
from pysal.model import spreg

np.random.seed(42)

# Data is assumed to be loaded with columns 'cart_x' and 'cart_y'
# GeoDataFrame creation with geometry based on coordinates
gdf = gpd.GeoDataFrame(data, geometry=gpd.points_from_xy(data['cart_x'], data['cart_y']))

# Create KNN weights with k=8 and row-standardize
w = weights.KNN.from_dataframe(gdf, k=8)
w.transform = 'R'  # Row-standardization

# %%
# model = spreg.ML_Lag(y, X, w, name_y='Travel time to nearest public hospital', name_x=['Distance to nearest public hospital'], name_w='KNN', name_ds='Hospital Data',slx_lags=1)




# moran = Moran(residuals, w)

# # Print Moran's I and p-value
# print(f"Moran's I: {moran.I}")
# print(f"P-value: {moran.p_sim}")

# %% [markdown]
# ## Question 1

# %%
y=hospital_data['Public hospital separations, 2012-13'].values
X=data['2012 ERP, total'].values
X_flat=X
X=X.reshape(-1,1)

# %%
np.random.seed(42)
# print correlation between X and y
correlation=np.corrcoef(X_flat,y)[0,1]
print(f'Correlation between X and y: {correlation}')

# fit a linear regression model
from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(X,y)

# print the r^2 score
r2=model.score(X,y)
print(f'R^2 score: {r2}')

# check autocorrelation of residuals
# compute residuals
y_pred=model.predict(X)
residuals=y-y_pred

# compute Moran's I
moran=Moran(residuals,w,permutations=9999)
print(f"Moran's I: {moran.I}")
print(f"P-value: {moran.p_sim}")



# do a scatter plot of X vs y
plt.figure(figsize=(5,5))
plt.scatter(X,y)
# plot the regression line
plt.plot(X,model.predict(X),color='black')
plt.xlabel('2012 ERP, total')
plt.ylabel('Public hospital separations, 2012-13')
plt.title('2012 ERP, total vs Public hospital separations, 2012-13',fontsize=10)
plt.legend(['Data','Regression Line'])

plt.text(0.65,0.01,f'R^2: {r2:.2f}',transform=plt.gca().transAxes)
plt.text(0.65,0.05,f'Correlation: {correlation:.2f}',transform=plt.gca().transAxes)
plt.text(0.65,0.10,f"Moran's I in Residual: {moran.I:.2f}",transform=plt.gca().transAxes)
plt.text(0.65,0.15,f"P-value: {moran.p_sim:.5f}",transform=plt.gca().transAxes)

plt.savefig('../doc/figures/2012_ERP_vs_Public_hospital_separations.png')

plt.show()
plt.clf()
# Out:
# Correlation between X and y: 0.9130294940418828
# R^2 score: 0.8336228569903767
# Moran's I: 0.21923678024746499
# P-value: 0.0023

# %%
model = spreg.ML_Lag(y, X, w, name_y='Public hospital separations, 2012-13', name_x=['2012 ERP, total'], name_w='KNN', name_ds='Hospital Data',slx_lags=1)

print(model.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: MAXIMUM LIKELIHOOD SPATIAL LAG WITH SLX - SPATIAL DURBIN MODEL (METHOD = FULL)
# -------------------------------------------------------------------------------------------------
# Data set            :Hospital Data
# Weights matrix      :         KNN
# Dependent Variable  :Public hospital separations, 2012-13                Number of Observations:          34
# Mean dependent var  :   2990.7151                Number of Variables   :           4
# S.D. dependent var  :   2441.5951                Degrees of Freedom    :          30
# Pseudo R-squared    :      0.8661
# Spatial Pseudo R-squared:  0.8363
# Log likelihood      :   -279.5096
# Sigma-square ML     : 775014.2214                Akaike info criterion :     567.019
# S.E of regression   :    880.3489                Schwarz criterion     :     573.125
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       369.29232      1008.42253         0.36621         0.71421
#      2012 ERP, total         0.26826         0.01801        14.89580         0.00000
#    W_2012 ERP, total        -0.19997         0.09199        -2.17380         0.02972
# W_Public hospital separations, 2012-13         0.61501         0.18869         3.25931         0.00112
# ------------------------------------------------------------------------------------
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                              DF         VALUE           PROB
# Common Factor Hypothesis Test     1          0.206           0.6502
#
# SPATIAL DURBIN MODEL IMPACTS
# Impacts computed using the 'simple' method.
#             Variable         Direct        Indirect          Total
#      2012 ERP, total         0.2683         -0.0909          0.1774
# ================================ END OF REPORT =====================================

# %% [markdown]
# ## Question 2

# %%
# population density vs distance to nearest public hospital
y=data['Population Density'].values
X=hospital_data['Distance to nearest public hospital'].values


X_flat=X
X=X.reshape(-1,1)

# %%
# print correlation between X and y
correlation=np.corrcoef(X_flat,y)[0,1]
print(f'Correlation between X and y: {correlation}')

# fit a linear regression model
model=LinearRegression()
model.fit(X,y)

# print the r^2 score
r2=model.score(X,y)
print(f'R^2 score: {r2}')

# check autocorrelation of residuals
# compute residuals
y_pred=model.predict(X)
residuals=y-y_pred

# compute Moran's I
moran=Moran(residuals,w,permutations=9999)
print(f"Moran's I: {moran.I}")
print(f"P-value: {moran.p_sim}")

# do a scatter plot of X vs y
plt.figure(figsize=(5,5))
plt.scatter(X,y)
# plot the regression line
plt.plot(X,model.predict(X),color='black')
plt.xlabel('Distance to nearest public hospital')
plt.ylabel('Population Density')
plt.title('Distance to nearest public hospital vs Population Density',fontsize=10)
plt.legend(['Data','Regression Line'])
# print the r^2 score, correlation between X and y, Moran's I and p-value within the plot
plt.text(0.05,0.01,f'R^2: {r2:.2f}',transform=plt.gca().transAxes)
plt.text(0.05,0.05,f'Correlation: {correlation:.2f}',transform=plt.gca().transAxes)
plt.text(0.05,0.10,f"Moran's I in Residual: {moran.I:.2f}",transform=plt.gca().transAxes)
plt.text(0.05,0.15,f"P-value: {moran.p_sim:.5f}",transform=plt.gca().transAxes)


plt.savefig('../doc/figures/Population_density_vs_Distance_to_nearest_public_hospital.png')

plt.show()
plt.clf()
# Out:
# Correlation between X and y: -0.7324317697067182
# R^2 score: 0.536456297275715
# Moran's I: 0.24136155413436255
# P-value: 0.001

# %%
model = spreg.ML_Lag(y, X, w, name_y='Population Density', name_x=['Distance to nearest public hospital'], name_w='KNN', name_ds='Hospital Data',slx_lags=1)

print(model.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: MAXIMUM LIKELIHOOD SPATIAL LAG WITH SLX - SPATIAL DURBIN MODEL (METHOD = FULL)
# -------------------------------------------------------------------------------------------------
# Data set            :Hospital Data
# Weights matrix      :         KNN
# Dependent Variable  :Population Density                Number of Observations:          34
# Mean dependent var  :   2992.8670                Number of Variables   :           4
# S.D. dependent var  :   1991.7270                Degrees of Freedom    :          30
# Pseudo R-squared    :      0.6553
# Spatial Pseudo R-squared:  0.5813
# Log likelihood      :   -288.6460
# Sigma-square ML     :1329295.4700                Akaike info criterion :     585.292
# S.E of regression   :   1152.9508                Schwarz criterion     :     591.397
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      2176.54008      1055.66292         2.06178         0.03923
# Distance to nearest public hospital      -242.92500        67.20887        -3.61448         0.00030
# W_Distance to nearest public hospital         7.15246       156.59789         0.04567         0.96357
# W_Population Density         0.60337         0.19316         3.12365         0.00179
# ------------------------------------------------------------------------------------
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                              DF         VALUE           PROB
# Common Factor Hypothesis Test     1          1.318           0.2509
#
# SPATIAL DURBIN MODEL IMPACTS
# Impacts computed using the 'simple' method.
#             Variable         Direct        Indirect          Total
# Distance to nearest public hospital      -242.9250       -351.5104       -594.4354
# ================================ END OF REPORT =====================================

# %% [markdown]
# ## Question 3

# %%
## Distance to nearest public hospital with emergency department vs Category 4 & 5 emergency department visits

y=hospital_data['Category 4 & 5 emergency department presentations, %'].values
X=hospital_data['Distance to nearest public hospital with emergency department'].values

X_flat=X
X=X.reshape(-1,1)

# %%
# print correlation between X and y
correlation=np.corrcoef(X_flat,y)[0,1]
print(f'Correlation between X and y: {correlation}')

# fit a linear regression model
model=LinearRegression()
model.fit(X,y)

# print the r^2 score
r2=model.score(X,y)
print(f'R^2 score: {r2}')

# check autocorrelation of residuals
# compute residuals
y_pred=model.predict(X)
residuals=y-y_pred

# compute Moran's I
moran=Moran(residuals,w,permutations=9999)
print(f"Moran's I: {moran.I}")
print(f"P-value: {moran.p_sim}")

# do a scatter plot of X vs y
plt.figure(figsize=(5,5))
plt.scatter(X,y)

# plot the regression line
plt.plot(X,model.predict(X),color='black')
plt.xlabel('Distance to nearest public hospital with emergency department',fontsize=8)
plt.ylabel('Category 4 & 5 emergency department presentations, %',fontsize=8)
# keep the title short
plt.title('Dist to nearest public hosp with ED vs Cat 4 & 5 ED presentations',fontsize=10)
plt.legend(['Data','Regression Line'])
# print the r^2 score, correlation between X and y, Moran's I and p-value within the plot
plt.text(0.05,0.01,f'R^2: {r2:.2f}',transform=plt.gca().transAxes)
plt.text(0.05,0.05,f'Correlation: {correlation:.2f}',transform=plt.gca().transAxes)
plt.text(0.05,0.10,f"Moran's I in Residual: {moran.I:.2f}",transform=plt.gca().transAxes)
plt.text(0.05,0.15,f"P-value: {moran.p_sim:.5f}",transform=plt.gca().transAxes)


plt.savefig('../doc/figures/Distance_to_nearest_public_hospital_with_ED_vs_Cat_4_5_ED_presentations.png')

plt.show()
plt.clf()
# Out:
# Correlation between X and y: -0.5493883475140706
# R^2 score: 0.3018275563842412
# Moran's I: 0.3518839345174029
# P-value: 0.0001

# %%
model = spreg.ML_Lag(y, X, w, name_y='Category 4 & 5 emergency department presentations, %', name_x=['Distance to nearest public hospital with emergency department'], name_w='KNN', name_ds='Hospital Data',slx_lags=1)

print(model.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: MAXIMUM LIKELIHOOD SPATIAL LAG WITH SLX - SPATIAL DURBIN MODEL (METHOD = FULL)
# -------------------------------------------------------------------------------------------------
# Data set            :Hospital Data
# Weights matrix      :         KNN
# Dependent Variable  :Category 4 & 5 emergency department presentations, %                Number of Observations:          34
# Mean dependent var  :     54.0974                Number of Variables   :           4
# S.D. dependent var  :      5.7537                Degrees of Freedom    :          30
# Pseudo R-squared    :      0.6102
# Spatial Pseudo R-squared:  0.3837
# Log likelihood      :    -92.6898
# Sigma-square ML     :     12.6555                Akaike info criterion :     193.380
# S.E of regression   :      3.5575                Schwarz criterion     :     199.485
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT        17.09197         8.16084         2.09439         0.03623
# Distance to nearest public hospital with emergency department        -0.41756         0.16923        -2.46749         0.01361
# W_Distance to nearest public hospital with emergency department        -0.33140         0.40984        -0.80861         0.41874
# W_Category 4 & 5 emergency department presentations, %         0.75407         0.12796         5.89315         0.00000
# ------------------------------------------------------------------------------------
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                              DF         VALUE           PROB
# Common Factor Hypothesis Test     1          3.902           0.0482
#
# SPATIAL DURBIN MODEL IMPACTS
# Impacts computed using the 'simple' method.
#             Variable         Direct        Indirect          Total
# Distance to nearest public hospital with emergency department        -0.4176         -2.6279         -3.0455
# ================================ END OF REPORT =====================================

# %% [markdown]
# # Overall SDM summary

# %%
import pandas as pd

# Final DataFrame
data_sdm = {
    "y": [
        "Public hospital separations, 2012-13",
        "Population Density",
        "Category 4 & 5 emergency department presentations, %"
    ],
    "X": [
        "2012 ERP, total",
        "Distance to nearest public hospital",
        "Distance to nearest public hospital with emergency department"
    ],
    "const": [369.29232, 2176.54008, 17.09197],
    "const_pval": [0.71421, 0.03923, 0.03623],
    "x_coef": [0.26826, -242.925, -0.41756],
    "x_pval": [0.00000, 0.00030, 0.01361],
    "y_lag": [0.61501, 0.60337, 0.75407],
    "y_pval": [0.00112, 0.00179, 0.00000],
    "x_lag": [-0.19997, 7.15246, -0.33140],
    "x_pval.1": [0.02972, 0.96357, 0.41874],
    "pR^2": [0.8661, 0.6553, 0.6102],
    "d_imp": [0.2683, -242.925, -0.4176],
    "i_imp": [-0.0909, -351.5104, -2.6279],
    "t_imp": [0.1774, -594.4354, -3.0455]
}

df = pd.DataFrame(data_sdm)
df
# Out:
#                                                    y  \
# 0               Public hospital separations, 2012-13
# 1                                 Population Density
# 2  Category 4 & 5 emergency department presentati...
#
#                                                    X       const  const_pval  \
# 0                                    2012 ERP, total   369.29232     0.71421
# 1                Distance to nearest public hospital  2176.54008     0.03923
# 2  Distance to nearest public hospital with emerg...    17.09197     0.03623
#
#       x_coef   x_pval    y_lag   y_pval    x_lag  x_pval.1    pR^2     d_imp  \
# 0    0.26826  0.00000  0.61501  0.00112 -0.19997   0.02972  0.8661    0.2683
# 1 -242.92500  0.00030  0.60337  0.00179  7.15246   0.96357  0.6553 -242.9250
# 2   -0.41756  0.01361  0.75407  0.00000 -0.33140   0.41874  0.6102   -0.4176
#
#       i_imp     t_imp
# 0   -0.0909    0.1774
# 1 -351.5104 -594.4354
# 2   -2.6279   -3.0455

# %%
print(df)
# Out:
#                                                    y  \
# 0               Public hospital separations, 2012-13
# 1                                 Population Density
# 2  Category 4 & 5 emergency department presentati...
#
#                                                    X       const  const_pval  \
# 0                                    2012 ERP, total   369.29232     0.71421
# 1                Distance to nearest public hospital  2176.54008     0.03923
# 2  Distance to nearest public hospital with emerg...    17.09197     0.03623
#
#       x_coef   x_pval    y_lag   y_pval    x_lag  x_pval.1    pR^2     d_imp  \
# 0    0.26826  0.00000  0.61501  0.00112 -0.19997   0.02972  0.8661    0.2683
# 1 -242.92500  0.00030  0.60337  0.00179  7.15246   0.96357  0.6553 -242.9250
# 2   -0.41756  0.01361  0.75407  0.00000 -0.33140   0.41874  0.6102   -0.4176
#
#       i_imp     t_imp
# 0   -0.0909    0.1774
# 1 -351.5104 -594.4354
# 2   -2.6279   -3.0455

# %%
# print column names
print(df.columns)
# Out:
# Index(['y', 'X', 'const', 'const_pval', 'x_coef', 'x_pval', 'y_lag', 'y_pval',
#        'x_lag', 'x_pval.1', 'pR^2', 'd_imp', 'i_imp', 't_imp'],
#       dtype='object')

# %%
# print hospital label reference
print(public_hospital_locs['Hospital'])
# Out:
# 0                                     The Alfred
# 1                       Royal Melbourne Hospital
# 2               Caulfield General Medical Centre
# 3              Monash Medical Centre (Moorabbin)
# 4                   Western Hospital (Footscray)
# 5                    Broadmeadows Health Service
# 6                               Rosebud Hospital
# 7                             Frankston Hospital
# 8                             Dandenong Hospital
# 9     Sandringham and District Memorial Hospital
# 10                            Maroondah Hospital
# 11                    Craigieburn Health Service
# 12                         St Vincent's Hospital
# 13               Monash Medical Centre (Clayton)
# 14                         The Northern Hospital
# Name: Hospital, dtype: object
